# %% [markdown]
# <a href="https://colab.research.google.com/github/B-Sumanth/2203A51551_NLP/blob/main/2203A51551_NLP_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Example text data (you can replace this with any larger corpus) text = """ Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her. [CO5]
# #### (i) Build the Transformer Model on above dataset
#
# #### (ii) Train the model using 20, 60, 70 epochs
#
#  ####  (iii) After training, use the model to generate new text by feeding it an initial seed text
#
# ####  (iv) Experimenting and Improving the Model by large dataset and hyper tune parameter.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, MultiHeadAttention, LayerNormalization, Dense, Dropout
from tensorflow.keras import Sequential, Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

text = """Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her."""

vocab_size = 1000
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts([text])

sequences = tokenizer.texts_to_sequences([text])[0]

input_sequences = []
for i in range(1, len(sequences)):
    input_sequences.append(sequences[:i+1])

max_sequence_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')

X, y = input_sequences[:,:-1], input_sequences[:,-1]
y = tf.keras.utils.to_categorical(y, num_classes=vocab_size)

class TransformerModel(Model):
    def __init__(self, vocab_size, embed_dim, num_heads, ff_dim):
        super(TransformerModel, self).__init__()
        self.embedding = Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.attention = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = Sequential([Dense(ff_dim, activation="relu"), Dense(embed_dim)])
        self.layernorm1 = LayerNormalization()
        self.layernorm2 = LayerNormalization()
        self.dropout1 = Dropout(0.1)
        self.dropout2 = Dropout(0.1)
        self.final_layer = Dense(vocab_size, activation="softmax")

    def call(self, inputs):
        x = self.embedding(inputs)
        attn_output = self.attention(x, x)
        x = self.layernorm1(x + self.dropout1(attn_output))
        ffn_output = self.dense_proj(x)
        x = self.layernorm2(x + self.dropout2(ffn_output))

        return self.final_layer(x[:, -1])

embed_dim = 128
num_heads = 4
ff_dim = 512

transformer_model = TransformerModel(vocab_size, embed_dim, num_heads, ff_dim)
transformer_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

epochs_list = [20,60,70]
for epochs in epochs_list:
    print(f"\nTraining model with {epochs} epochs:")
    transformer_model.fit(X, y, epochs=epochs, verbose=1)

def generate_text(model, tokenizer, seed_text, max_length=50):
    for _ in range(max_length):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=-1).item()
        output_word = tokenizer.index_word.get(predicted_word_index, "")
        seed_text += " " + output_word
    return seed_text

seed_text = "Once upon a time"
print("\nGenerated text:", generate_text(transformer_model, tokenizer, seed_text))
# Out:
# Training model with 20 epochs:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.0000e+00 - loss: 7.0461
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.1491 - loss: 5.9900
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.3189 - loss: 5.3331
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.2652 - loss: 4.8991
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.4610 - loss: 4.3848
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.7227 - loss: 3.8456
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7799 - loss: 3.3687
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.7383 - loss: 3.0035
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step - accuracy: 0.7816 - loss: 2.6134
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - accuracy: 0.7278 - loss: 2.2842
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.7695 - loss: 1.9157
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.7712 - loss: 1.6879
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - accuracy: 0.8250 - loss: 1.4315
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - accuracy: 0.7816 - loss: 1.2737
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - accuracy: 0.7504 - loss: 1.1581
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.7712 - loss: 1.0088
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8267 - loss: 0.8762
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.8405 - loss: 0.8166
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.8735 - loss: 0.7727
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8839 - loss: 0.6586
#
# Training model with 60 epochs:
# Epoch 1/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8839 - loss: 0.5954
# Epoch 2/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.9307 - loss: 0.5359
# Epoch 3/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9290 - loss: 0.5193
# Epoch 4/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.8977 - loss: 0.5350
# Epoch 5/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9186 - loss: 0.4623
# Epoch 6/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.8752 - loss: 0.4603
# Epoch 7/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9186 - loss: 0.4324
# Epoch 8/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.9307 - loss: 0.3845
# Epoch 9/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9081 - loss: 0.3724
# Epoch 10/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.8977 - loss: 0.3936
# Epoch 11/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9081 - loss: 0.3624
# Epoch 12/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9081 - loss: 0.3547
# Epoch 13/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9186 - loss: 0.3394
# Epoch 14/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.9411 - loss: 0.2947
# Epoch 15/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.9290 - loss: 0.2891
# Epoch 16/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.8977 - loss: 0.3185
# Epoch 17/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.9428 - loss: 0.2951
# Epoch 18/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9324 - loss: 0.2695
# Epoch 19/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9653 - loss: 0.2743
# Epoch 20/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9081 - loss: 0.2652
# Epoch 21/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.8977 - loss: 0.2538
# Epoch 22/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9307 - loss: 0.2308
# Epoch 23/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9307 - loss: 0.2236
# Epoch 24/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9203 - loss: 0.2297
# Epoch 25/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9290 - loss: 0.1921
# Epoch 26/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9203 - loss: 0.2157
# Epoch 27/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9532 - loss: 0.2001
# Epoch 28/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9186 - loss: 0.1862
# Epoch 29/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9324 - loss: 0.2001
# Epoch 30/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.9307 - loss: 0.1977
# Epoch 31/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9532 - loss: 0.1538
# Epoch 32/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9081 - loss: 0.1797
# Epoch 33/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.9324 - loss: 0.1866
# Epoch 34/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9532 - loss: 0.1529
# Epoch 35/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9758 - loss: 0.1487
# Epoch 36/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9428 - loss: 0.1594
# Epoch 37/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 0.9428 - loss: 0.1454
# Epoch 38/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.9532 - loss: 0.1420
# Epoch 39/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.9653 - loss: 0.1424
# Epoch 40/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9653 - loss: 0.1228
# Epoch 41/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - accuracy: 0.9775 - loss: 0.1314
# Epoch 42/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.9775 - loss: 0.1226
# Epoch 43/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 0.9775 - loss: 0.1155
# Epoch 44/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.1247
# Epoch 45/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9549 - loss: 0.1112
# Epoch 46/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9879 - loss: 0.0959
# Epoch 47/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9653 - loss: 0.1063
# Epoch 48/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9879 - loss: 0.0930
# Epoch 49/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9758 - loss: 0.1010
# Epoch 50/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9775 - loss: 0.1083
# Epoch 51/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.1021
# Epoch 52/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9758 - loss: 0.0927
# Epoch 53/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9515 - loss: 0.1056
# Epoch 54/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.9758 - loss: 0.1004
# Epoch 55/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9758 - loss: 0.1080
# Epoch 56/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9775 - loss: 0.1386
# Epoch 57/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.9775 - loss: 0.1033
# Epoch 58/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9394 - loss: 0.1467
# Epoch 59/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9653 - loss: 0.1208
# Epoch 60/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9186 - loss: 0.2576
#
# Training model with 70 epochs:
# Epoch 1/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9290 - loss: 0.1531
# Epoch 2/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9428 - loss: 0.1381
# Epoch 3/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.9653 - loss: 0.1463
# Epoch 4/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.9324 - loss: 0.1367
# Epoch 5/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 0.9758 - loss: 0.0995
# Epoch 6/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.9428 - loss: 0.1507
# Epoch 7/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 0.9775 - loss: 0.1254
# Epoch 8/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.9775 - loss: 0.1127
# Epoch 9/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9653 - loss: 0.1028
# Epoch 10/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9775 - loss: 0.0969
# Epoch 11/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9879 - loss: 0.0886
# Epoch 12/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9775 - loss: 0.0920
# Epoch 13/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9775 - loss: 0.0854
# Epoch 14/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9879 - loss: 0.0701
# Epoch 15/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9775 - loss: 0.0784
# Epoch 16/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9775 - loss: 0.0803
# Epoch 17/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9879 - loss: 0.0619
# Epoch 18/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9879 - loss: 0.0682
# Epoch 19/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0660
# Epoch 20/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9775 - loss: 0.0732
# Epoch 21/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.9775 - loss: 0.0707
# Epoch 22/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9879 - loss: 0.0563
# Epoch 23/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9879 - loss: 0.0582
# Epoch 24/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0603
# Epoch 25/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9653 - loss: 0.0767
# Epoch 26/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9636 - loss: 0.0790
# Epoch 27/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9775 - loss: 0.0601
# Epoch 28/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.9549 - loss: 0.0796
# Epoch 29/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9879 - loss: 0.0579
# Epoch 30/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9775 - loss: 0.0789
# Epoch 31/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - accuracy: 0.9775 - loss: 0.0591
# Epoch 32/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.9775 - loss: 0.0597
# Epoch 33/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.9879 - loss: 0.0403
# Epoch 34/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9775 - loss: 0.0567
# Epoch 35/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9775 - loss: 0.0509
# Epoch 36/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.9775 - loss: 0.0515
# Epoch 37/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9775 - loss: 0.0532
# Epoch 38/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9879 - loss: 0.0461
# Epoch 39/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9775 - loss: 0.0450
# Epoch 40/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 1.0000 - loss: 0.0356
# Epoch 41/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0440
# Epoch 42/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 1.0000 - loss: 0.0313
# Epoch 43/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 1.0000 - loss: 0.0319
# Epoch 44/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0454
# Epoch 45/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9879 - loss: 0.0367
# Epoch 46/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9879 - loss: 0.0331
# Epoch 47/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 1.0000 - loss: 0.0344
# Epoch 48/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9879 - loss: 0.0325
# Epoch 49/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9775 - loss: 0.0428
# Epoch 50/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.9879 - loss: 0.0267
# Epoch 51/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 1.0000 - loss: 0.0382
# Epoch 52/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9775 - loss: 0.0394
# Epoch 53/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9879 - loss: 0.0329
# Epoch 54/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 1.0000 - loss: 0.0278
# Epoch 55/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9775 - loss: 0.0395
# Epoch 56/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - accuracy: 0.9879 - loss: 0.0327
# Epoch 57/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9775 - loss: 0.0542
# Epoch 58/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.9758 - loss: 0.1395
# Epoch 59/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.9428 - loss: 0.2131
# Epoch 60/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.9064 - loss: 0.2791
# Epoch 61/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - accuracy: 0.8960 - loss: 0.2476
# Epoch 62/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9064 - loss: 0.3370
# Epoch 63/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9081 - loss: 0.1671
# Epoch 64/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.9411 - loss: 0.1749
# Epoch 65/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9324 - loss: 0.2124
# Epoch 66/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9879 - loss: 0.1104
# Epoch 67/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9186 - loss: 0.1528
# Epoch 68/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9653 - loss: 0.1241
# Epoch 69/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9653 - loss: 0.1115
# Epoch 70/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9428 - loss: 0.1267
#
# Generated text: Once upon a time there was a time there was a time there was a little girl named red riding hood she loved to visit her mother asked her mother asked her to take a basket of goodies to her grandmother on her way through the woods she met a big bad wolf who
